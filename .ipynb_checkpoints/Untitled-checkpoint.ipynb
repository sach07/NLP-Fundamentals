# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
#from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.stem import WordNetLemmatizer
import string
from gensim import corpora, models
import gensim
import pyLDAvis.gensim

# %%
df=pd.read_csv('votedkaggle.csv')

# %%
df.head()
# Out:
#                          Title  \
# 0  Credit Card Fraud Detection
# 1     European Soccer Database
# 2      TMDB 5000 Movie Dataset
# 3    Global Terrorism Database
# 4      Bitcoin Historical Data
#
#                                             Subtitle  \
# 0  Anonymized credit card transactions labeled as...
# 1  25k+ matches, players & teams attributes for E...
# 2                Metadata on ~5,000 movies from TMDb
# 3  More than 170,000 terrorist attacks worldwide,...
# 4  Bitcoin data at 1-min intervals from select ex...
#
#                           Owner  Votes  \
# 0  Machine Learning Group - ULB   1241
# 1                  Hugo Mathien   1046
# 2     The Movie Database (TMDb)   1024
# 3              START Consortium    789
# 4                        Zielak    618
#
#                                             Versions  \
# 0          Version 2,2016-11-05|Version 1,2016-11-03
# 1  Version 10,2016-10-24|Version 9,2016-10-24|Ver...
# ...

# %%
texts=[]
for i in df['Description'].iteritems():
    raw = str(i[1]).lower()
    tokens = nltk.word_tokenize(raw)
    newwords=[words for words in tokens if words not in stopwords.words('english')]
    lemma_tokens = [lemmatizer.lemmatize(newwords) for newwords in newwords]
    texts.append(new_lemma_tokens)

# %%
texts
# Out:
# [['context',
#   'birth',
#   'u.s',
#   '1994',
#   '2003.',
#   'content',
#   'data',
#   'set',
#   'following',
#   'structure',
#   'year',
#   'year',
#   'month',
#   'month',
#   'date_of_month',
#   'day',
#   'number',
#   'month',
#   'day_of_week',
#   'day',
#   'week',
#   'monday',
#   'sunday',
#   'birth',
#   'number',
#   'birth',
#   'acknowledgement',
#   'data',
#   'set',
#   'center',
#   'disease',
#   'control',
#   'prevention',
#   "'s",
#   'national',
#   'national',
#   'center',
#   'health',
#   'statistic',
#   'inspiration',
#   'make',
#   'dictionary',
#   'show',
#   'total',
#   'number',
#   'birth',
#   'day',
#   'week'],
#  ['context',
#   'birth',
#   'u.s',
#   '1994',
#   '2003.',
#   'content',
#   'data',
#   'set',
#   'following',
#   'structure',
#   'year',
#   'year',
#   'month',
#   'month',
#   'date_of_month',
#   'day',
#   'number',
#   'month',
#   'day_of_week',
#   'day',
#   'week',
#   'monday',
#   'sunday',
# ...

# %%
dictionary = corpora.Dictionary(texts[:5])
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus[:5], num_topics=2, id2word = dictionary, passes=20)
print(ldamodel.top_topics(corpus[:5],topn=2))
# Out:
# [([(0.079980269, 'birth'), (0.060462311, 'month')], 1.000088900581841e-12), ([(0.030771704, 'birth'), (0.030693902, 'number')], 1.000088900581841e-12)]

# %%
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(ldamodel, corpus[:5], dictionary)
# Out:
# exception calling callback for <Future at 0x22ce90f1a90 state=finished raised TerminatedWorkerError>
# Traceback (most recent call last):
#   File "C:\Users\Sachin\Anaconda3\lib\site-packages\joblib\externals\loky\_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\Sachin\Anaconda3\lib\site-packages\joblib\parallel.py", line 309, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\Sachin\Anaconda3\lib\site-packages\joblib\parallel.py", line 731, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "C:\Users\Sachin\Anaconda3\lib\site-packages\joblib\parallel.py", line 759, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\Sachin\Anaconda3\lib\site-packages\joblib\parallel.py", line 716, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\Sachin\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 510, in apply_async
# ...
